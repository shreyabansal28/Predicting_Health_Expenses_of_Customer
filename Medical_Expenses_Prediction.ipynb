# %% [markdown]
# <a href="https://colab.research.google.com/github/aditibansal17/Predicting_Health_Expenses_of_Customer/blob/main/Medical_Expenses_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# lets import the required libraries

# for mathemaical operations
import numpy as np
# for dataframe manipulations
import pandas as pd

# for data visualizations
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# setting parameters for visualization
plt.rcParams['figure.figsize'] = (16, 5)
plt.style.use('fivethirtyeight')

# %%
# lets read the data set
data = pd.read_csv('med-insurance.csv')
data.shape
# Out:
# (1338, 7)

# %%
# lets check the head of the dataset
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# lets check the missing values in the dataset
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
# lets check the descriptive summary
data.describe().style.background_gradient(cmap = 'Greens')
# Out:
# <style type="text/css">
# #T_004e2_row0_col0, #T_004e2_row0_col1, #T_004e2_row0_col2, #T_004e2_row7_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_004e2_row0_col3, #T_004e2_row1_col2, #T_004e2_row2_col0, #T_004e2_row2_col1, #T_004e2_row2_col2, #T_004e2_row3_col0, #T_004e2_row3_col2, #T_004e2_row3_col3, #T_004e2_row4_col2, #T_004e2_row5_col2, #T_004e2_row6_col2, #T_004e2_row7_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_004e2_row1_col0, #T_004e2_row1_col1, #T_004e2_row5_col0, #T_004e2_row5_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_004e2_row1_col3 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_004e2_row2_col3 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_004e2_row3_col1, #T_004e2_row4_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_004e2_row4_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_004e2_row4_col3 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_004e2_row5_col3 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_004e2_row6_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_004e2_row6_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_004e2_row6_col3 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_004e2_row7_col0, #T_004e2_row7_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# </style>
# <table id="T_004e2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >bmi</th>
#       <th class="col_heading level0 col2" >children</th>
#       <th class="col_heading level0 col3" >expenses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_004e2_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_004e2_row0_col0" class="data row0 col0" >1338.000000</td>
#       <td id="T_004e2_row0_col1" class="data row0 col1" >1338.000000</td>
#       <td id="T_004e2_row0_col2" class="data row0 col2" >1338.000000</td>
#       <td id="T_004e2_row0_col3" class="data row0 col3" >1338.000000</td>
#     </tr>
#     <tr>
#       <th id="T_004e2_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_004e2_row1_col0" class="data row1 col0" >39.207025</td>
#       <td id="T_004e2_row1_col1" class="data row1 col1" >30.665471</td>
#       <td id="T_004e2_row1_col2" class="data row1 col2" >1.094918</td>
#       <td id="T_004e2_row1_col3" class="data row1 col3" >13270.422414</td>
#     </tr>
#     <tr>
#       <th id="T_004e2_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_004e2_row2_col0" class="data row2 col0" >14.049960</td>
#       <td id="T_004e2_row2_col1" class="data row2 col1" >6.098382</td>
#       <td id="T_004e2_row2_col2" class="data row2 col2" >1.205493</td>
#       <td id="T_004e2_row2_col3" class="data row2 col3" >12110.011240</td>
#     </tr>
#     <tr>
#       <th id="T_004e2_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_004e2_row3_col0" class="data row3 col0" >18.000000</td>
#       <td id="T_004e2_row3_col1" class="data row3 col1" >16.000000</td>
#       <td id="T_004e2_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_004e2_row3_col3" class="data row3 col3" >1121.870000</td>
#     </tr>
#     <tr>
#       <th id="T_004e2_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_004e2_row4_col0" class="data row4 col0" >27.000000</td>
#       <td id="T_004e2_row4_col1" class="data row4 col1" >26.300000</td>
#       <td id="T_004e2_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_004e2_row4_col3" class="data row4 col3" >4740.287500</td>
#     </tr>
#     <tr>
#       <th id="T_004e2_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_004e2_row5_col0" class="data row5 col0" >39.000000</td>
#       <td id="T_004e2_row5_col1" class="data row5 col1" >30.400000</td>
#       <td id="T_004e2_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_004e2_row5_col3" class="data row5 col3" >9382.030000</td>
#     </tr>
#     <tr>
#       <th id="T_004e2_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_004e2_row6_col0" class="data row6 col0" >51.000000</td>
#       <td id="T_004e2_row6_col1" class="data row6 col1" >34.700000</td>
#       <td id="T_004e2_row6_col2" class="data row6 col2" >2.000000</td>
#       <td id="T_004e2_row6_col3" class="data row6 col3" >16639.915000</td>
#     </tr>
#     <tr>
#       <th id="T_004e2_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_004e2_row7_col0" class="data row7 col0" >64.000000</td>
#       <td id="T_004e2_row7_col1" class="data row7 col1" >53.100000</td>
#       <td id="T_004e2_row7_col2" class="data row7 col2" >5.000000</td>
#       <td id="T_004e2_row7_col3" class="data row7 col3" >63770.430000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Univariate Analysis

# %%
# lets check the distribution of smoker, children and region

plt.subplot(1, 3, 1)
plt.pie(data['smoker'].value_counts().values,
        labels = data['smoker'].value_counts().index,
        colors = ['gold','silver'],
        startangle = 90,
        shadow = True,
       explode = [0.1, 0])

plt.subplot(1, 3, 2)
sns.countplot(data['children'], palette = 'magma')
plt.grid()

plt.subplot(1, 3, 3)
plt.pie(data['region'].value_counts().values,
        labels = data['region'].value_counts().index,
        colors = ['gold','silver','grey','black'],
        startangle = 90,
        shadow = True,
       explode = [0.1, 0, 0, 0])
plt.suptitle('Distribution of Smoker, Children and Regions', fontsize = 15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# lets check the distribution of age, bmi and expenses

plt.subplot(1, 3, 1)
sns.distplot(data['age'], color = 'black')
plt.xlabel('Age')
plt.grid()

plt.subplot(1, 3, 2)
sns.distplot(data['bmi'], color = 'orange')
plt.xlabel('BMI')
plt.grid()

plt.subplot(1, 3, 3)
sns.distplot(data['expenses'], color = 'aqua')
plt.xlabel('Expenses')
plt.grid()

plt.suptitle('Distribution of Age, BMI, and Expenses', fontsize = 15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Bivariate Analysis

# %%
# lets understand the impact of age on Medical Expenses
px.scatter(data, y = 'expenses',
           x = 'age',
           marginal_y = 'violin',
           trendline = 'ols')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="72282b28-4982-4fbe-ae24-7dde027bc65c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72282b28-4982-4fbe-ae24-7dde027bc65c")) {                    Plotly.newPlot(                        "72282b28-4982-4fbe-ae24-7dde027bc65c",                        [{"hovertemplate":"age=%{x}<br>expenses=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[19,18,28,33,32,31,46,37,37,60,25,62,23,56,27,19,52,23,56,30,60,30,18,34,37,59,63,55,23,31,22,18,19,63,28,19,62,26,35,60,24,31,41,37,38,55,18,28,60,36,18,21,48,36,40,58,58,18,53,34,43,25,64,28,20,19,61,40,40,28,27,31,53,58,44,57,29,21,22,41,31,45,22,48,37,45,57,56,46,55,21,53,59,35,64,28,54,55,56,38,41,30,18,61,34,20,19,26,29,63,54,55,37,21,52,60,58,29,49,37,44,18,20,44,47,26,19,52,32,38,59,61,53,19,20,22,19,22,54,22,34,26,34,29,30,29,46,51,53,19,35,48,32,42,40,44,48,18,30,50,42,18,54,32,37,47,20,32,19,27,63,49,18,35,24,63,38,54,46,41,58,18,22,44,44,36,26,30,41,29,61,36,25,56,18,19,39,45,51,64,19,48,60,27,46,28,59,35,63,40,20
fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ## Multivariate Analysis

# %%
# As we can see from the above chart that having 4 and 5 childrens is having similar impact on expenses
# so let's cap these values

data['children'] = data['children'].replace((4, 5), (3, 3))

# lets check the value counts
data['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    200
# Name: children, dtype: int64

# %%
px.scatter(data,
        x="expenses",
                 y="age",
                 facet_row="children",
                 facet_col="region",
                 color="smoker",
                 trendline="ols")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dbbb80af-5bc1-4ea0-8954-fa84d0173ead" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbbb80af-5bc1-4ea0-8954-fa84d0173ead")) {                    Plotly.newPlot(                        "dbbb80af-5bc1-4ea0-8954-fa84d0173ead",                        [{"hovertemplate":"smoker=yes<br>children=0<br>region=southwest<br>expenses=%{x}<br>age=%{y}<extra></extra>","legendgroup":"yes","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"yes","showlegend":true,"x":[16884.92,36837.47,35585.58,48173.36,15820.7,17081.08,48824.45,34779.62,16297.85,34838.87,35491.64,13844.51,37079.37,22144.03,36197.7,17496.31,34472.84,39727.61,34166.27,52590.83,20167.34,16232.85,34828.65,37829.72,33900.65],"xaxis":"x13","y":[19,30,22,60,38,19,63,19,19,27,34,19,33,42,29,32,24,49,23,60,20,20,19,43,25],"yaxis":"y13","type":"scattergl"},{"hovertemplate":"<b>OLS trendline</b><br>age = 0.000799188 * expenses + 6.86363<br>R<sup>2</sup>=0.426576<br><br>smoker=yes<br>children=0<br>region=southwest<br>expenses=%{x}<br>age=%{y} <b>(trend)</b><extra></extra>","legendgroup":"yes","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"yes","showlegend":false,"x":[13844.51,15820.7,16232.85,16297.85,16884.92,17081.08,17496.31,20167.34,22144.03,33900.65,34166.27,34472.84,34779.62,34828.65,34838.87,35491.64,35585.58,36197.7,36837.47,37079.37,37829.72,39727.61,48173.36,48824.45,52590.83],"xaxis":"x13","y":[17.927998702027427,19.507346518210504,19.836731953031983,19.88867918890095,20.357858631387046,20.51462739735716,20.846474331970583,22.981130107710506,24.56087751801565,33.95663001281336,34.1689103942213,34.413917534226684,34.65909250376335,34.69827670337343,34.70644440722852,35.22813051735449,35.30320626100881,35.79240536901055,36.30370203196273,36.49702566821971,37.09669656720866,38.61346794387573,45.36321205680426,45.88355553068007,48.89360214963655],"yaxis":"y13","type":"scattergl"},{"hovertemplate":"smoker=yes<br>children=0<br>region=southeast<br>expenses=%{x}<br>age=%{y}<extra></extra>","legendgroup":"yes","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"yes","showlegend":false,"x":[27808.73,39611.76,37742.58,16577.78,47055.53,21223.68,36950.26,36149.48,37133.9,19515.54,38126.25,46889.26,46599.11,48885.14,32548.34,63770.43,45863.21,34439.86,27037.91,44400.41,40419.02,18246.5,19539.24,23065.42,36307.8,21195.82,38792.69,27533.91,45008.96,40974.16,48673.56,44423.8,34672.15,41676.08,39722.75,19350.37,26125.67,26926.51,17043.34,62592.87],"xaxis":"x14","y":[62,27,36,27,63,48,30,18,27,42,24,64,61,44,19,54,43,19,64,51,37,27,37,47,18,53,18,57,60,48,60,55,28,47,19,31,20,64,26,45],"yaxis":"y14","type":"scattergl"},{"hovertemplate":"<b>OLS trendline</b><br>age = 0.000343532 * expenses + 28.2993<br>R<sup>2</sup>=0.065248<br><br>smoker=yes<br>children=0<br>region=southeast<br>expenses=%{x}<br>age=%{y} <b>(trend)</b><extra></extra>","legendgroup":"yes","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":
,13470.86,5974.38,3044.21,11455.28,5240.77,25656.58,3994.18,9866.3,5397.62,11482.63,24059.68,9861.03,14043.48,5972.38,8825.09,8233.1,6196.45,3056.39,13887.2,63770.43,11538.42,3213.62,45863.21,3972.92,11187.66,17878.9,39983.43,9193.84,10923.93,2801.26,2128.43,6373.56,11552.9,3761.29,2219.45,4753.64,31620.0,13224.06,12222.9,58571.07,3206.49,17626.24,4779.6,43943.88,13635.64,5976.83,11842.44,15359.1,8823.99,7640.31,5594.85,33471.97,1633.04,11070.54,16085.13,17468.98,9283.56,3558.62,25678.78,8547.69,6571.54,2207.7,6753.04,1880.07,42969.85,11658.12,34439.86,10713.64,9182.17,3736.46,42983.46,3366.67,2709.11,24915.05,4466.62,8252.28,12430.95,9800.89,10579.71,8280.62,8527.53,12244.53,24667.42,3410.32,26392.26,14394.4,22192.44,5148.55,27037.91,40003.33,6500.24,3943.6,6185.32,46200.99,12485.8,10156.78,2585.27,4766.02,26236.58,3578.0,3201.25,29186.48,3500.61,2020.55,9541.7,5385.34,8930.93,5375.04,44400.41,6113.23,5469.01,10107.22,8310.84,2457.5,9566.99,10848.13,12231.61,9875.68,10106.13,40932.43,16657.72,2217.6,6781.35,4234.93,9447.25,14007.22,9583.89,40419.02,3757.84,9910.36,8556.91,19539.24,11833.78,7985.82,23065.42,3925.76,9095.07,11842.62,7050.64,14319.03,6933.24,11150.78,12797.21,17748.51,24520.26,4 ...

# %% [markdown]
# * This Chart clearly depits that the Southeast region has higher expenses compared to other regions.
# * This Chart clearly shows that Males have Higher Expenses in general in all the regions.

# %%
# lets check the impact of Regions in Expenses

data[['expenses', 'region']].groupby(['region']).agg(['min','mean','max']).style.background_gradient(cmap = 'Wistia')
# Out:
# <style type="text/css">
# #T_5baa7_row0_col0, #T_5baa7_row2_col1, #T_5baa7_row2_col2 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_5baa7_row0_col1 {
#   background-color: #ffc706;
#   color: #000000;
# }
# #T_5baa7_row0_col2 {
#   background-color: #ffb900;
#   color: #000000;
# }
# #T_5baa7_row1_col0 {
#   background-color: #fe9000;
#   color: #f1f1f1;
# }
# #T_5baa7_row1_col1 {
#   background-color: #e7fc6f;
#   color: #000000;
# }
# #T_5baa7_row1_col2 {
#   background-color: #ffaa00;
#   color: #000000;
# }
# #T_5baa7_row2_col0, #T_5baa7_row3_col1, #T_5baa7_row3_col2 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# #T_5baa7_row3_col0 {
#   background-color: #faec2a;
#   color: #000000;
# }
# </style>
# <table id="T_5baa7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="3">expenses</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >min</th>
#       <th class="col_heading level1 col1" >mean</th>
#       <th class="col_heading level1 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5baa7_level0_row0" class="row_heading level0 row0" >northeast</th>
#       <td id="T_5baa7_row0_col0" class="data row0 col0" >1694.800000</td>
#       <td id="T_5baa7_row0_col1" class="data row0 col1" >13406.384691</td>
#       <td id="T_5baa7_row0_col2" class="data row0 col2" >58571.070000</td>
#     </tr>
#     <tr>
#       <th id="T_5baa7_level0_row1" class="row_heading level0 row1" >northwest</th>
#       <td id="T_5baa7_row1_col0" class="data row1 col0" >1621.340000</td>
#       <td id="T_5baa7_row1_col1" class="data row1 col1" >12417.575169</td>
#       <td id="T_5baa7_row1_col2" class="data row1 col2" >60021.400000</td>
#     </tr>
#     <tr>
#       <th id="T_5baa7_level0_row2" class="row_heading level0 row2" >southeast</th>
#       <td id="T_5baa7_row2_col0" class="data row2 col0" >1121.870000</td>
#       <td id="T_5baa7_row2_col1" class="data row2 col1" >14735.411538</td>
#       <td id="T_5baa7_row2_col2" class="data row2 col2" >63770.430000</td>
#     </tr>
#     <tr>
#       <th id="T_5baa7_level0_row3" class="row_heading level0 row3" >southwest</th>
#       <td id="T_5baa7_row3_col0" class="data row3 col0" >1241.570000</td>
#       <td id="T_5baa7_row3_col1" class="data row3 col1" >12346.937908</td>
#       <td id="T_5baa7_row3_col2" class="data row3 col2" >52590.830000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# as we can see that all the columns are important, we will not remove any column
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# ### Data Processing

# %%
# lets perform encoding

# as we know males have higher expense than females, lets encode males as 2, and females as 1,
# similarly smokers, have highers expense, so we will encode smokers as 2, and non smokers as 1,
# as we know that the south east region has higher expense than other regions

data['sex'] = data['sex'].replace(('male','female'), (2, 1))
data['smoker'] = data['smoker'].replace(('yes','no'), (2, 1))
data['region'] = data['region'].replace(('southeast','southwest','northeast','northwest'),(2, 1, 1, 1))

# let's check whether any categorical column is left
data.select_dtypes('object').columns
# Out:
# Index([], dtype='object')

# %%
# now lets check our data again
data.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    1  27.9         0       2       1  16884.92
# 1   18    2  33.8         1       1       2   1725.55
# 2   28    2  33.0         3       1       2   4449.46
# 3   33    2  22.7         0       1       1  21984.47
# 4   32    2  28.9         0       1       1   3866.86

# %%
# lets form dependent and independent sets

y = data['expenses']
x = data.drop(['expenses'], axis = 1)

print(y.shape)
print(x.columns)
# Out:
# (1338,)
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region'], dtype='object')

# %%
# lets perform train test split

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1070, 6)
# (268, 6)
# (1070,)
# (268,)

# %%
# lets perform standardization

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ## Predictive Modelling

# %%
# lets create the Model

# lets create a simple Linear Regression Model
from sklearn.linear_model import LinearRegression

model1 = LinearRegression()
model1.fit(x_train, y_train)

y_pred1 = model1.predict(x_test)

# %%
# lets check the Model accuracy
from sklearn.metrics import r2_score, mean_squared_error

mse = mean_squared_error(y_test, y_pred1)
rmse = np.sqrt(mse)
print("RMSE Score :", rmse)

r2_score = r2_score(y_test, y_pred1)
print("R2 Score :",r2_score)
# Out:
# RMSE Score : 5665.098223602283
# R2 Score : 0.7983199562954781

# %%
# lets create a Random Forest Model

from sklearn.ensemble import RandomForestRegressor

model2 = RandomForestRegressor()
model2.fit(x_train, y_train)

y_pred2 = model2.predict(x_test)

# lets check the Model accuracy
from sklearn.metrics import r2_score, mean_squared_error

mse = mean_squared_error(y_test, y_pred2)
rmse = np.sqrt(mse)
print("RMSE Score :", rmse)

r2_score = r2_score(y_test, y_pred2)
print("R2 Score :",r2_score)
# Out:
# RMSE Score : 4422.511699843626
# R2 Score : 0.877090339416283

# %%
# lets create a Gradient Boosting Model

from sklearn.ensemble import GradientBoostingRegressor

model3 = GradientBoostingRegressor()
model3.fit(x_train, y_train)

y_pred3 = model3.predict(x_test)

# lets check the Model accuracy
from sklearn.metrics import r2_score, mean_squared_error

mse = mean_squared_error(y_test, y_pred3)
rmse = np.sqrt(mse)
print("RMSE Score :", rmse)

r2_score = r2_score(y_test, y_pred3)
print("R2 Score :",r2_score)
# Out:
# RMSE Score : 4094.5685268946436
# R2 Score : 0.8946427743065142

# %%
# lets create an ensemble by averaging

avg_model = (y_pred1 + y_pred2 + y_pred3)/3

# lets check the Model accuracy
from sklearn.metrics import r2_score, mean_squared_error

mse = mean_squared_error(y_test, avg_model)
rmse = np.sqrt(mse)
print("RMSE Score :", rmse)

r2_score = r2_score(y_test, avg_model)
print("R2 Score :",r2_score)
# Out:
# RMSE Score : 4283.077089668729
# R2 Score : 0.884718446384215

# %%
# lets create an weighted averaging model

# lets give 50% weight to gradient boosting
# 30% weight to random forest
# and 20% weight to linear regression

weight_avg_model = 0.2*y_pred1 + 0.3*y_pred2 + 0.5*y_pred3

# lets check the Model accuracy
from sklearn.metrics import r2_score, mean_squared_error

mse = mean_squared_error(y_test, weight_avg_model)
rmse = np.sqrt(mse)
print("RMSE Score :", rmse)

r2_score = r2_score(y_test, weight_avg_model)
print("R2 Score :",r2_score)
# Out:
# RMSE Score : 4159.384635821942
# R2 Score : 0.8912808108060675

# %%
## lets perform cross validaion

from sklearn.model_selection import cross_val_score
scores = cross_val_score(model3, x, y, cv=5)
print(scores)
# Out:
# [0.87582727 0.79239073 0.89223153 0.84640679 0.85862323]

# %% [markdown]
# * as we can see that the scores are not varying much, so we can say that this model is good.

# %% [markdown]
# ## Comparison of Models

# %%
r2_score = np.array([0.79, 0.87, 0.89])
labels = np.array(['Linear Regression', 'Random Forest' 'Gradient Boosting'])
index = np.argsort(r2_score)
color = plt.cm.rainbow(np.linspace(0, 1, 4))

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (4, 4)

plt.bar(range(len(index)), r2_score[index], color = color)
plt.xticks(range(0, 3), ['Linear Regression', 'Random Forest','Gradient Boosting'], rotation = 90)
plt.title('Comparison of r2 Score', fontsize = 15)
plt.show()

# %%
input_data = (31,1,25.74,0,1,0)

# changing input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model3.predict(input_data_reshaped)
print(prediction)

print('The insurance cost is USD ', prediction[0])
# Out:
# [56086.82494055]
# The insurance cost is USD  56086.82494054819

# %%
from tkinter import *

# %%
import joblib

# %%
from matplotlib.pyplot import *
from matplotlib.widgets import *
from math import *
from random import *
from numpy import *
from tkinter import *

# %%
# !apt-get install python3-tk
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-tk is already the newest version (3.6.9-1~18.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 62 not upgraded.

# %%
master = Tk()
#master.title("cost prediction")
#label = Label(master,text = "cost prediction",bg = "black",fg = "white").grid(row=0 , columnspan=2)
#mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-49-921c06037837> in <module>()
# ----> 1 master = Tk()
#       2 #master.title("cost prediction")
#       3 #label = Label(master,text = "cost prediction",bg = "black",fg = "white").grid(row=0 , columnspan=2)
#       4 #mainloop()
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
import pickle

# %%
with open('model_pkl', 'wb') as files:
    pickle.dump(model3, files)

# %%
pip install flask-ngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.4)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25
